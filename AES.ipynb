# %% [markdown]
# # Criptogradando um arquivo com AES estilo CBC </br>
# Pedro Amaro <br>
# Utilizando a biblioteca https://pycryptodome.readthedocs.io/en/latest/src/cipher/classic.html#cbc-mode

# %%
# !pip install PyCryptodome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyCryptodome
#   Downloading pycryptodome-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 19.0 MB/s
# Installing collected packages: PyCryptodome
# Successfully installed PyCryptodome-3.16.0

# %%
import json, os, struct
from base64 import b64encode, b64decode
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad
from Crypto.Random import get_random_bytes

# %%
fpath = "/content/msg.txt" #caminho do arquivo a ser criptografado
key = b'1234567891011009' #chave, tamanho precisa ser 16bits

# %%
def encode_with_aes (fpath, key):
  f = open(fpath, "r")
  data = f.read().encode()

  cipher = AES.new(key, AES.MODE_CBC)

  ct_bytes = cipher.encrypt(pad(data, AES.block_size))

  iv = b64encode(cipher.iv).decode('utf-8')
  ct = b64encode(ct_bytes).decode('utf-8')
  result = json.dumps({'iv':iv, 'ciphertext':ct})

  return result

def decode_with_aes(json_input):
  try:
      b64 = json.loads(json_input)
      iv = b64decode(b64['iv'])
      ct = b64decode(b64['ciphertext'])
      cipher = AES.new(key, AES.MODE_CBC, iv)
      pt = unpad(cipher.decrypt(ct), AES.block_size)
      return pt
  except (ValueError, KeyError):
      print("Incorrect decryption")

# %%
cipher_text = encode_with_aes(fpath, key)
cipher_text
# Out:
# '{"iv": "fB/+m3mnS8gKGATlk8RoTw==", "ciphertext": "..."}'

# %%
msg = decode_with_aes(cipher_text)
print(msg)
# Out:
# b'NOME: Contos de Leoa: Problemas de Mentira\nPLAYERS: 4 + lucas\nFORMATO: Voz pelo discord // roll20\nSISTEMA: Tales from the Loop\n\nPLOT:\nOs players s\xc3\xa3o crian\xc3\xa7as entre 12 e 15 anos. Eles vivem em uma cidade relativamente pequena no interior do Norte/Nordeste do Brasil, Leoa. O ano \xc3\xa9 2005. Algumas crian\xc3\xa7as de outros estados e pa\xc3\xadses v\xc3\xaam estudar na mesma escola dos players, a \xc3\xbanica da cidade, pois seus pais trabalham na empresa de Pecu\xc3\xa1ria Caprina e de derivados local, cujo dono \xc3\xa9 o atual prefeito.\n\nEles v\xc3\xa3o pra escola e tudo \xc3\xa9 normal. Algumas crian\xc3\xa7as estranhas frequentam a escola, elas sofrem bastante bullying. Alguns garotos e garotas s\xc3\xa3o populares. Alguns gostam de livros, outros de esporte\xe2\x80\xa6 Tudo como em uma escola normal.\nMuitos adolescentes v\xc3\xa3o estudar em outras cidades quando terminam a escola.\n\nEnt\xc3\xa3o, um dos amigos dos players desaparece, algum tempo depois o corpo morto \xc3\xa9 encontrado. Os pais est\xc3\xa3o devastados. Os professores informam aos demais alunos.\nO player morto n\xc3\xa3o foi o \xc3\xbanico, outras crian\xc3\xa7as desapareceram, algumas encontradas, outras n\xc3\xa3o. A pol\xc3\xadcia n\xc3\xa3o parece estar fazendo um bom trabalho investigando esse caso, n\xc3\xa3o est\xc3\xa3o nem perto de descobrir quem \xc3\xa9 o assassino. Talvez sem lista de suspeitos, talvez com uma lista curta.\n\nO assassino \xc3\xa9 um homem gordo, de por volta dos 40 anos, que vive no por\xc3\xa3o da casa da fam\xc3\xadlia. Ele nunca conseguiu se adaptar \xc3\xa0 sociedade, seus pr\xc3\xb3prios pais o desprezam. \xc3\x89 uma pessoa arrogante, s\xc3\xa1dica, tem um complexo de superioridade e \xc3\xa9 pedofilo.\nEm sua inf\xc3\xa2ncia, al\xc3\xa9m de ser um garoto gordo e feio, o que n\xc3\xa3o o ajudava nos olhos dos outros, se comportava de forma estranha e desagradavel ao redor das outras pessoas, principalmente das crian\xc3\xa7as mais novas. Tamb\xc3\xa9m maltratava animais, chegando algumas vezes a mat\xc3\xa1-los e dissec\xc3\xa1-los. \nDevido a esse comportamento, seus pais sentiam extrema vergonha, decep\xc3\xa7\xc3\xa3o e raiva do filho. Sem d\xc3\xbavida, a forma como tratavam ele foi um dos estopins para esse comportamento, e as surras, gritos e castigos s\xc3\xb3 pioraram. Ao inv\xc3\xa9s de tentar entend\xc3\xaa-lo e ajud\xc3\xa1-lo, decidiram apenas escond\xc3\xaa-lo, fingir que nunca o tiveram. O PAI POLICIAL, ESCONDE O FILHO DA SOCIEDADE DEVIDO A CARREIRA (DIZ QUE EST\xc3\x81 MORTO OU QUE EST\xc3\x81 MORANDO COM OS AV\xc3\x93S EM OUTRA CIDADE). DEVIDO A ISSO, NINGU\xc3\x89M, NEM MESMO ELE, SUSPEITA QUE O FILHO \xc3\x89 O ASSASSINO.\n\nO assassino \xc3\xa9 um grande f\xc3\xa3 de animes e mang\xc3\xa1s, um hobbie muito peculiar na \xc3\xa9poca. Tamb\xc3\xa9m \xc3\xa9 uma das poucas pessoas na cidade a ter um computador em casa, no por\xc3\xa3o onde vive, para ser mais espec\xc3\xadfico. Ele ganha seu dinheiro, pela internet, mas quem o mant\xc3\xa9m mesmo s\xc3\xa3o os pais, pagando por sua alimenta\xc3\xa7\xc3\xa3o, eletricidade e etc. Tudo relacionado aos assassinatos, ele pagou com o pr\xc3\xb3prio dinheiro. Nada aparece nas despesas dos pais.\nUma das obras que o assassino mais gosta \xc3\xa9 Monster, de Naoki Urasawa. Johan \xc3\xa9 uma grande fonte de inspira\xc3\xa7\xc3\xa3o para ele, e uma das poucas pessoas, mesmo n\xc3\xa3o sendo real, com quem ele conseguiu formar um la\xc3\xa7o, se sentir entendido. A maior parte dos pontos sobre o bem prevalecer passaram sobre a cabe\xc3\xa7a do assassino, ou ele simplesmente discorda deles, vendo o seu bem, sua verdade e a verdade de Johan como a correta. Ele tamb\xc3\xa9m n\xc3\xa3o tem interesse de ver o mundo queimar ou de morrer, pelo menos n\xc3\xa3o no n\xc3\xadvel de Johan, mas o respeita.\n\nPara os assassinatos, ele usa de m\xc3\xa9todos como os de Johan para se aproximar de outros criminosos. Ele os espiona, manda cartas e mensag ...
